# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import itertools
import corner
import APL1_functions as AC

# %%
# --- config lists (reuse yours) ---
embryos = [1, 3, 5, 10, 20]
abin = [50, 75, 100, 300]
migration = ["migration", "insitu"]

# %%
# --- examples matching your notation ---

# 1) Your original example:
# fixed: migration='migration', embryo=10 AU; vary abin across [50,75,100,300]
res_mig_abin_1 = AC.load_series(embryo=1, migration_type="migration", vary="abin")
res_mig_abin_3 = AC.load_series(embryo=3, migration_type="migration", vary="abin")
res_mig_abin_5 = AC.load_series(embryo=5, migration_type="migration", vary="abin")
res_mig_abin_10 = AC.load_series(embryo=10, migration_type="migration", vary="abin")
res_mig_abin_20 = AC.load_series(embryo=20, migration_type="migration", vary="abin")

res_ins_abin_1 = AC.load_series(embryo=1, migration_type="insitu", vary="abin")
res_ins_abin_3 = AC.load_series(embryo=3, migration_type="insitu", vary="abin")
res_ins_abin_5 = AC.load_series(embryo=5, migration_type="insitu", vary="abin")
res_ins_abin_10 = AC.load_series(embryo=10, migration_type="insitu", vary="abin")
res_ins_abin_20 = AC.load_series(embryo=20, migration_type="insitu", vary="abin")



time_ins_abin_10 = res_ins_abin_10["time"]
core_mass_ins_abin_10 = res_ins_abin_10["core_mass"]
env_mass_ins_abin_10 = res_ins_abin_10["env_mass"]
tot_mass_ins_abin_10 = res_ins_abin_10["tot_mass"]
mean_distance_ins_abin_10 = res_ins_abin_10["mean_distance"]


# Access like your arrays:
time_mig_abin_1 = res_mig_abin_1["time"]
core_mass_mig_abin_1 = res_mig_abin_1["core_mass"]
env_mass_mig_abin_1 = res_mig_abin_1["env_mass"]
tot_mass_mig_abin_1 = res_mig_abin_1["tot_mass"]
mean_distance_mig_abin_1 = res_mig_abin_1["mean_distance"]

time_mig_abin_3 = res_mig_abin_3["time"]
core_mass_mig_abin_3 = res_mig_abin_3["core_mass"]
env_mass_mig_abin_3 = res_mig_abin_3["env_mass"]
tot_mass_mig_abin_3 = res_mig_abin_3["tot_mass"]
mean_distance_mig_abin_3 = res_mig_abin_3["mean_distance"]

time_mig_abin_5 = res_mig_abin_5["time"]
core_mass_mig_abin_5 = res_mig_abin_5["core_mass"]
env_mass_mig_abin_5 = res_mig_abin_5["env_mass"]
tot_mass_mig_abin_5 = res_mig_abin_5["tot_mass"]
mean_distance_mig_abin_5 = res_mig_abin_5["mean_distance"]

time_mig_abin_10 = res_mig_abin_10["time"]
core_mass_mig_abin_10 = res_mig_abin_10["core_mass"]
env_mass_mig_abin_10 = res_mig_abin_10["env_mass"]
tot_mass_mig_abin_10 = res_mig_abin_10["tot_mass"]
mean_distance_mig_abin_10 = res_mig_abin_10["mean_distance"]

time_mig_abin_20 = res_mig_abin_20["time"]
core_mass_mig_abin_20 = res_mig_abin_20["core_mass"]
env_mass_mig_abin_20 = res_mig_abin_20["env_mass"]
tot_mass_mig_abin_20 = res_mig_abin_20["tot_mass"]
mean_distance_mig_abin_20 = res_mig_abin_20["mean_distance"]
# Out:
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("C:\\Users\\casey\\Downloads\\setB\\setB" + str(file_path), delim_whitespace=True, header=None)
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("C:\\Users\\casey\\Downloads\\setB\\setB" + str(file_path), delim_whitespace=True, header=None)
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:26: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_mig_abin_10)):
    plt.scatter(time_mig_abin_10[ii], tot_mass_mig_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Total Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_mig_abin_10)):
    plt.scatter(time_mig_abin_10[ii], env_mass_mig_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Envelope Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_mig_abin_10)):
    plt.scatter(time_mig_abin_10[ii], core_mass_mig_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Core Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_mig_abin_10)):
    plt.scatter(time_mig_abin_10[ii], mean_distance_mig_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Mean Distance")
plt.legend()

# %%
plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_ins_abin_10)):
    plt.scatter(time_ins_abin_10[ii], tot_mass_ins_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Total Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_ins_abin_10)):
    plt.scatter(time_ins_abin_10[ii], env_mass_ins_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Envelope Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_ins_abin_10)):
    plt.scatter(time_ins_abin_10[ii], core_mass_ins_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Core Mass")
plt.legend()

plt.subplots(figsize=(6, 4))
plt.xscale("log")
for ii in range(len(time_ins_abin_10)):
    plt.scatter(time_ins_abin_10[ii], mean_distance_ins_abin_10[ii], s=1, label='Binary Separation ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Mean Distance")
plt.legend()

# %%
red_color = ['lightcoral','indianred','firebrick','maroon']
blue_color = ['skyblue','deepskyblue','dodgerblue','steelblue']
green_color = ['palegreen','chartreuse','forestgreen','darkgreen']
purple_color = ['violet','blueviolet','purple','indigo']
yellow_color = ['khaki','gold','goldenrod','darkgoldenrod']

plt.subplots(figsize=(12, 8))
plt.xscale("log")
for ii in [3]:
    plt.scatter(time_mig_abin_1[ii], tot_mass_mig_abin_1[ii], s=1, label="red = embryo at 1",color=red_color[ii])
    plt.scatter(time_mig_abin_1[ii], core_mass_mig_abin_1[ii], s=1, color=red_color[ii-1])
    
    plt.scatter(time_mig_abin_3[ii], tot_mass_mig_abin_3[ii], s=1, label="blue = embryo at 3",color=blue_color[ii])
    plt.scatter(time_mig_abin_3[ii], core_mass_mig_abin_3[ii], s=1, color=blue_color[ii-1])
    
    plt.scatter(time_mig_abin_5[ii], tot_mass_mig_abin_5[ii], s=1,  label="green = embryo at 5",color=green_color[ii])
    plt.scatter(time_mig_abin_5[ii], core_mass_mig_abin_5[ii], s=1, color=green_color[ii-1])
    
    plt.scatter(time_mig_abin_10[ii], tot_mass_mig_abin_10[ii], s=1, label="purple = embryo at 10",color=purple_color[ii])
    plt.scatter(time_mig_abin_10[ii], core_mass_mig_abin_10[ii], s=1, color=purple_color[ii-1])
    
    plt.scatter(time_mig_abin_20[ii], tot_mass_mig_abin_20[ii], s=1,  label="yellow = embryo at 20",color=yellow_color[ii])
    plt.scatter(time_mig_abin_20[ii], core_mass_mig_abin_20[ii], s=1, color=yellow_color[ii-1])
    
    plt.title('Binary separation of ' + str(abin[ii]))
plt.xlabel("Time")
plt.ylabel("Total Mass")
plt.legend()

# %%
""" Pebble flux, mean distance"""
# Out:
# ' Pebble flux, mean distance'
