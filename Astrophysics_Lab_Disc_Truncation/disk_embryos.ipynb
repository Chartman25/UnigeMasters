# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.optimize import curve_fit
import itertools
import corner
from typing import Iterable, Dict, List, Any
import APL1_functions as AC

# %%
embryos = [1, 3, 5, 10, 20]
abin = [50, 75, 100, 300]
migration = ["migration", "insitu"]

paths = {}
"""
How To call a specific path

paths["migration"][abin][embryos] 
"""
for mig in migration:
    paths[mig] = {}
    for a in abin:
        paths[mig][a] = {}
        for e in embryos:
            path = (
                f"\\1embryo@{e}au_0.1Mdisk_0.01fpg_0.01fopacity_alpha1e-3_kanag"
                f"\\abin{a}au_{mig}\\tracks_001.outputdat"
            )
            paths[mig][a][e] = path



"""
When working with pandas dataframes I will store arrays of dataframes using the following notation
df_migration_abin_embryos

When I vary one of the varaibles, I will keep that name the same and change the other two to their chosen values

i.e. df_mig_abin_10 means that I am looking just at migrations with embryos placed at 5 AU, but varying the binary separation
"""

# For migration @ embryo=1
res_mig_10 = AC.build_series(paths, AC, "migration", abin[:3], 1, Plotting=True)


# For in-situ @ embryo=1
res_insitu_10 = AC.build_series(paths, AC, "insitu", abin[:3], 1, Plotting=True)


# For migration @ embryo=3
res_mig_10 = AC.build_series(paths, AC, "migration", abin[:3], 3, Plotting=True)


# For in-situ @ embryo=3
res_insitu_10 = AC.build_series(paths, AC, "insitu", abin[:3], 3, Plotting=True)


# For migration @ embryo=5
res_mig_10 = AC.build_series(paths, AC, "migration", abin[:], 5, Plotting=True)


# For in-situ @ embryo=5
res_insitu_10 = AC.build_series(paths, AC, "insitu", abin[:], 5, Plotting=True)


# For migration @ embryo=10
res_mig_10 = AC.build_series(paths, AC, "migration", abin[:], 10, Plotting=True)


# For in-situ @ embryo=10
res_insitu_10 = AC.build_series(paths, AC, "insitu", abin[:], 10, Plotting=True)

# For migration @ embryo=20
res_mig_10 = AC.build_series(paths, AC, "migration", abin[1:], 20, Plotting=True)


# For in-situ @ embryo=20
res_insitu_10 = AC.build_series(paths, AC, "insitu", abin[1:], 20, Plotting=True)
# Out:
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:28: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("C:\\Users\\casey\\Downloads\\setB\\setB" + str(file_path), delim_whitespace=True, header=None)
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:28: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("C:\\Users\\casey\\Downloads\\setB\\setB" + str(file_path), delim_whitespace=True, header=None)
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:28: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
single_star_migration_10AU = AC.build_disk_series(AC,embryo=10,migration_type="migration",system_type="abin50au",Plotting=True)
# Out:
# c:\Users\casey\UnigeMasters\Astrophysics_Lab_Disc_Truncation\APL1_functions.py:28: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("C:\\Users\\casey\\Downloads\\setB\\setB" + str(file_path), delim_whitespace=True, header=None)
