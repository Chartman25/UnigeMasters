# %%
import matplotlib.pyplot as plt
import numpy as np
import Functions as AC
# Out:
# c:\Users\casey\UnigeMasters\Astrophysics_and_Data_Analysis\Functions.py:17: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("C:\\Users\\casey\\UnigeMasters\\Astrophysics_and_Data_Analysis\Databases\\" + str(file_path),  usecols=['t','y', 'ey'])

# %%
df1 = AC.data_loader("dataFile.csv")
t1 = df1['t']
y1 = df1['y']
ey1 = df1['ey']

df2 = AC.data_loader("dataFile2.csv")
t2 = df2['t']
y2 = df2['y']
ey2 = df2['ey']

# %%
plt.errorbar(t1, y1, yerr = ey1,fmt ='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(t2, y2, yerr = ey2,fmt ='o', color='g')
# Out:
# <ErrorbarContainer object of 3 artists>
